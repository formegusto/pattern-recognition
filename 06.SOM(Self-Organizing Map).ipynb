# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn as sk
import sklearn.cluster as cluster

# %%
x = np.random.randn(10000)
y = np.random.randn(10000)

df = pd.DataFrame({"x":x, "y": y})
df["dis"] = df["x"]**2+df["y"]**2
df["cla"] = df["dis"].apply(lambda x:1 if 0.5<x<1.0 else 2 if 3<x<4 else 0)
df["cla"].value_counts()
# Out:
# 0    7424
# 1    1745
# 2     831
# Name: cla, dtype: int64

# %%
df=df[df["cla"] != 0]
df
# Out:
#              x         y       dis  cla
# 1    -0.802058  1.788941  3.843609    2
# 6     0.701316 -0.221777  0.541029    1
# 16    0.722402 -1.695580  3.396855    2
# 25    0.412038 -0.672263  0.621713    1
# 28   -1.236637  1.226175  3.032776    2
# ...        ...       ...       ...  ...
# 9975  0.212661 -1.931373  3.775427    2
# 9985 -0.833208 -0.392019  0.847914    1
# 9986 -0.930453  0.280613  0.944486    1
# 9987  0.336645 -0.645047  0.529415    1
# 9997  0.834090 -0.393448  0.850507    1
#
# [2576 rows x 4 columns]

# %%
sns.scatterplot(df["x"], df["y"], hue=df["cla"])
# Out:
# /Users/formegusto/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
from somlearn import SOM
import somoclu

# %%
CLUSTER = SOM(n_columns=1, n_rows=2, gridtype="hexagonal", random_state=70)
y_pred = CLUSTER.fit_predict(df)
df["pred"] = y_pred
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d5de4cd9d644> in <module>
#       1 CLUSTER = SOM(n_columns=1, n_rows=2, gridtype="hexagonal", random_state=70)
# ----> 2 y_pred = CLUSTER.fit_predict(df)
#       3 df["pred"] = y_pred
#       4 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/somlearn/som.py in fit_predict(self, X, y, **fit_params)
#     275             Index of the cluster each sample belongs to.
#     276         """
# --> 277         return self.fit(X, **fit_params).labels_
#
# ~/opt/anaconda3/lib/python3.8/site-packages/somlearn/som.py in fit(self, X, y, **fit_params)
#     240
#     241         # Fit Somoclu
# --> 242         self.algorithm_.train(data=X, **fit_params)
#     243
#     244         # Grid labels
#
# ~/opt/anaconda3/lib/python3.8/site-packages/somoclu/train.py in train(self, data, epochs, radius0, radiusN, radiuscooling, scale0, scaleN, scalecooling)
#     220         self.umatrix.shape = (self._n_rows * self._n_columns, )
#     221         self.bmus.shape = (self.n_vectors * 2, )
# --> 222         wrap_train(np.ravel(self._data), epochs, self._n_columns, self._n_rows,
#     223                    self.n_dim, self.n_vectors, radius0, radiusN,
#     224                    radiuscooling, scale0, scaleN, scalecooling,
#
# NameError: name 'wrap_train' is not defined
